# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import csv
import numpy as np
import pandas as pd

# %%
# f = open('public_data.csv', 'r')
# rdr = csv.reader(f)
# pm = []
# time = []
# for line in rdr:
#     pm.append(line[3])
#     time.append(line[2])
# f.close()

# pm = pm[1:]
# time = time[1:]

# %%
data = pd.read_csv("public_data2.csv", sep=",",engine='python',encoding='CP949')

# %%
data
# Out:
#       지점 지점명                일시  pm10
# 0    108  서울   2021-03-22 1:00    35
# 1    108  서울   2021-03-22 2:00    37
# 2    108  서울   2021-03-22 3:00    36
# 3    108  서울   2021-03-22 4:00    38
# 4    108  서울   2021-03-22 5:00    47
# ..   ...  ..               ...   ...
# 137  108  서울  2021-03-27 18:00    83
# 138  108  서울  2021-03-27 19:00    82
# 139  108  서울  2021-03-27 20:00    73
# 140  108  서울  2021-03-27 21:00    66
# 141  108  서울   2021-03-28 0:00    61
#
# [142 rows x 4 columns]

# %%
plt.figure(figsize=(16,9))
data['pm10'].plot()
plt.show()

# %%
X = np.array(data['pm10'])

# %%
X.shape
# Out:
# (142,)
