# %%
from numpy import array
from keras.models import Sequential
from keras.layers import Dense, LSTM
import tensorflow as tf

x = array([[1, 2, 3],[2, 3, 4],[3, 4, 5],[4, 5, 6]])
y = array([4, 5, 6, 7])

print('x shape : ', x.shape)
print('y shape : ', y.shape)
# Out:
# x shape :  (4, 3)
# y shape :  (4,)

# %%
print(x)
print('-------x reshape-----------')
x = x.reshape((x.shape[0], x.shape[1], 1))
print('x shape : ', x.shape)
print(x)
# Out:
# [[1 2 3]
#  [2 3 4]
#  [3 4 5]
#  [4 5 6]]
# -------x reshape-----------
# x shape :  (4, 3, 1)
# [[[1]
#   [2]
#   [3]]
#
#  [[2]
#   [3]
#   [4]]
#
#  [[3]
#   [4]
#   [5]]
#
#  [[4]
#   [5]
#   [6]]]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, LSTM

# %%
model = Sequential()
model.add(LSTM(40, activation="relu", input_shape=(3,1)))
# DENSE와 사용법 동일하나 input_shape=(열, 몇개씩잘라작업)
model.add(Dense(5))
model.add(Dense(1))
 
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 40)                6720
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 205
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 6,931
# Trainable params: 6,931
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mse')
model.fit(x, y, epochs=100, batch_size=1)

x_input = array([6,7,8])
x_input = x_input.reshape((1,3,1))
 
yhat = model.predict(x_input)
print(yhat)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 1ms/step - loss: 31.9799
# Epoch 2/100
# 4/4 [==============================] - 0s 1ms/step - loss: 28.5877
# Epoch 3/100
# 4/4 [==============================] - 0s 1ms/step - loss: 25.5737
# Epoch 4/100
# 4/4 [==============================] - 0s 1ms/step - loss: 22.6358
# Epoch 5/100
# 4/4 [==============================] - 0s 1ms/step - loss: 19.9559
# Epoch 6/100
# 4/4 [==============================] - 0s 1ms/step - loss: 17.6015
# Epoch 7/100
# 4/4 [==============================] - 0s 1ms/step - loss: 15.0705
# Epoch 8/100
# 4/4 [==============================] - 0s 1ms/step - loss: 12.1661
# Epoch 9/100
# 4/4 [==============================] - 0s 1ms/step - loss: 9.8063
# Epoch 10/100
# 4/4 [==============================] - 0s 1ms/step - loss: 7.3599
# Epoch 11/100
# 4/4 [==============================] - 0s 1ms/step - loss: 5.1124
# Epoch 12/100
# 4/4 [==============================] - 0s 1ms/step - loss: 3.3460
# Epoch 13/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.9399
# Epoch 14/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1131
# Epoch 15/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8608
# Epoch 16/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7983
# Epoch 17/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0583
# Epoch 18/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0582
# Epoch 19/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0217
# Epoch 20/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7563
# Epoch 21/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6995
# Epoch 22/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6882
# Epoch 23/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7151
# Epoch 24/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6935
# Epoch 25/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6674
# Epoch 26/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6452
# Epoch 27/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6228
# Epoch 28/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6380
# Epoch 29/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5981
# Epoch 30/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6018
# Epoch 31/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5736
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5611
# Epoch 33/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5443
# Epoch 34/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5330
# Epoch 35/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5248
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5117
# Epoch 37/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4967
# Epoch 38/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4844
# Epoch 39/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4757
# Epoch 40/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4680
# Epoch 41/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4515
# Epoch 42/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4525
# Epoch 43/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4338
# Epoch 44/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4281
# Epoch 45/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4147
# Epoch 46/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4122
# Epoch 47/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3970
# Epoch 48/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3777
# Epoch 49/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3720
# Epoch 50/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3701
# Epoch 51/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3519
# Epoch 52/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3457
# Epoch 53/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3342
# Epoch 54/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3232
# Epoch 55/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3178
# Epoch 56/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3088
# Epoch 57/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2957
# Epoch 58/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2918
# Epoch 59/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2799
# Epoch 60/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2758
# Epoch 61/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2670
# Epoch 62/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2565
# Epoch 63/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2527
# Epoch 64/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2415
# Epoch 65/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2368
# Epoch 66/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2353
# Epoch 67/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2247
# Epoch 68/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2139
# Epoch 69/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2063
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2000
# Epoch 71/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1942
# Epoch 72/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1927
# Epoch 73/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1852
# Epoch 74/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1772
# Epoch 75/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1711
# Epoch 76/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1726
# Epoch 77/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1619
# Epoch 78/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1573
# Epoch 79/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1492
# Epoch 80/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1483
# Epoch 81/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1414
# Epoch 82/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1401
# Epoch 83/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1323
# Epoch 84/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1256
# Epoch 85/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1218
# Epoch 86/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1180
# Epoch 87/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1131
# Epoch 88/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1088
# Epoch 89/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1076
# Epoch 90/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1048
# Epoch 91/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1012
# Epoch 92/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0956
# Epoch 93/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0907
# Epoch 94/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0877
# Epoch 95/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0855
# Epoch 96/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0831
# Epoch 97/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0802
# Epoch 98/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0767
# Epoch 99/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0739
# Epoch 100/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0707
# [[9.359338]]
